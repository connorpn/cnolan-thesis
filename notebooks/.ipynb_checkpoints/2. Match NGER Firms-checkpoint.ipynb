# %% [markdown]
# This notebook matches unique nger firm names to publically listed firms during the sample pariod and appends the corresponding ticker. This allows for nger data to be merged with firm data for further analysis.

# %%
import os
import pandas as pd
import numpy as np
from fuzzywuzzy import process

# %%
working_directory = 'C:/cnolan-thesis/' #set location using back slashes

os.chdir(working_directory)

print("Current working directory: {0}".format(os.getcwd()))


def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
            output_path = os.makedirs(directory)
            print(output_path)
    except OSError:
        print ('Error: Creating directory. ' +  directory)
        

# Folder where outputs will be saved (by default a folder within the working directory) 
createFolder('./output/') 
output_path = working_directory +'./output/'
# Out:
# Current working directory: C:\cnolan-thesis

# %% [markdown]
# # Import Data

# %%
#THIS DATA IS COLLATED AND PROCESSED FROM NOTEBOOK: 1. Collate Data
nger_data = pd.read_csv('https://raw.githubusercontent.com/connorpn/cnolan-thesis/main/output/nger_data.csv',encoding = "ISO-8859-1")
ms_data = pd.read_csv ('https://raw.githubusercontent.com/connorpn/cnolan-thesis/main/output/ms_data.csv', encoding='latin1')

# %% [markdown]
# # Fuzzy Match NGER and Morningstar Firm Names (This Process Takes A Long Time)

# %%
ms_firms = ms_data[['ticker', 'morningstar_name']]
ms_firms = ms_firms.drop_duplicates(subset=['morningstar_name'])

ms_firms_list = []
ms_firms_list = ms_data['morningstar_name'].unique().tolist()

nger_firms_list = []
nger_firms_list = nger_data['nger_name'].unique().tolist()


threshold = 95 #note: in preliminary analysis a threshold of 95 provided matching without mismatching 
names_response = []
for name in nger_firms_list:
    resp_match =  process.extractOne(name,ms_firms_list)
    if resp_match[1] > threshold:
         row = {'nger_name':name,'morningstar_name':resp_match[0], 'match_score':resp_match[1]}
         names_response.append(row)

matched_firms = pd.DataFrame(names_response)

matched_firms_tickers = pd.merge(matched_firms[['nger_name', 'morningstar_name', 'match_score']],
                            ms_firms[['ticker', 'morningstar_name']],
                                          on = ['morningstar_name'],
                                          how = 'left')

matched_firms_tickers["matched"] = 1
matched_firms_tickers = matched_firms_tickers.reindex(columns=['nger_name', 'morningstar_name', 'ticker','matched','match_score'])

"Save Matched Firms File"
output_filename = 'matched_firms_tickers.csv'
outputname = output_path + output_filename
matched_firms_tickers.to_csv(outputname, mode='w')
print("Exported File: " + outputname)

#ticker list for datastream series search
matched_tickers = matched_firms_tickers['ticker']

"Save Matched Firms List File"
output_filename = 'matched_tickers_list.csv'
outputname = output_path + output_filename
matched_tickers_list.to_csv(outputname, mode='w')
print("Exported File: " + outputname)
# Out:
# Exported File: C:/cnolan-thesis/./output/matched_firms_tickers.csv
# Exported File: C:/cnolan-thesis/./output/matched_tickers_list.csv

# %% [markdown]
# # Append Matched Data to NGER Data and Filter (Matched Only NGER Data)

# %%
nger_data_matched = pd.merge(nger_data[['year', 'nger_name', 'scope1', 'scope2', 'energy_consumption', 'total_emissions']], matched_firms_tickers[['nger_name', 'morningstar_name', 'match_score', 'ticker','matched']], on = ['nger_name'], how = 'left')
nger_data_matched = nger_data_matched.dropna(axis=0, how= 'any', subset=['matched'])
print(list(nger_data_matched))
# Out:
# ['year', 'nger_name', 'scope1', 'scope2', 'energy_consumption', 'total_emissions', 'morningstar_name', 'match_score', 'ticker', 'matched']

# %%
nger_data_matched = nger_data_matched.reindex(columns=['year', 'nger_name', 'morningstar_name', 'ticker', 'match_score', 'matched', 'scope1', 'scope2', 'energy_consumption', 'total_emissions'])
nger_data_matched = nger_data_matched.reset_index(drop=True)

"Save Matched NGER Data"
output_filename = 'nger_data_matched.csv'
outputname = output_path + output_filename
nger_data_matched.to_csv(outputname, mode='w', index=False)
print("Exported File: " + outputname)
# Out:
# Exported File: C:/cnolan-thesis/./output/nger_data_matched.csv

# %% [markdown]
# # Display Matched Firms

# %%
print('Number of Matched Firms:')
print(len(matched_firms_tickers))
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(matched_firms_tickers)
# Out:
# Number of Matched Firms:
# 91
#                               nger_name                     morningstar_name  \
# 0                             abb grain                            abb grain
# 1                 aditya birla minerals                aditya birla minerals
# 2                            agl energy                           agl energy
# 3                                   amp                                  amp
# 4                          arrow energy                         arrow energy
# 5                               asciano                              asciano
# 6        babcock & brown infrastructure       babcock & brown infrastructure
# 7                       bluescope steel                      bluescope steel
# 8                                 boral                                boral
# 9                               bradken                              bradken
# 10                           brickworks                           brickworks
# 11              centennial coal company              centennial coal company
# 12                    centro properties                    centro properties
# 13                     coca-cola amatil                     coca-cola amatil
# 14       commonwealth bank of australia       commonwealth bank of australia
# 15                                  csr                                  csr
# 16                                dexus                                dexus
# 17                           downer edi                           downer edi
# 18                  energy developments                  energy developments
# 19                             envestra                             envestra
# 20                      felix resources                      felix resources
# 21                     fortescue metals                     fortescue metals
# 22                             foster's                             foster's
# 23                      goodman fielder                      goodman fielder
# 24                            graincorp                            graincorp
# 25                     grange resources                     grange resources
# 26                        harvey norman                        harvey norman
# 27                                  hrl                                  hrl
# 28                      iluka resources                      iluka resources
# 29                        incitec pivot                        incitec pivot
# 30                          bega cheese                          bega cheese
# 31                                crane                                crane
# 32                          david jones                          david jones
# 33                        fairfax media                        fairfax media
# 34                          healthscope                          healthscope
# 35                               kagara                               kagara
# 36                       ardent leisure                       ardent leisure
# 37                           automotive                           automotive
# 38                        cbh resources                        cbh resources
# 39                         charter hall                         charter hall
# 40                                  csl                                  csl
# 41                     eastern star gas                     eastern star gas
# 42                               elders                               elders
# 43                            erm power                            erm power
# 44                      gloucester coal                      gloucester coal
# 45                                gunns                                gunns
# 46                     investa property                     investa property
# 47                    lindsay australia                    lindsay australia
# 48                       redbank energy                       redbank energy
# 49                central norseman gold                central norseman gold
# 50                        centro retail                        centro retail
# 51                     evolution mining                     evolution mining
# 52                       focus minerals                       focus minerals
# 53                       integra mining                       integra mining
# 54                           atlas iron                           atlas iron
# 55                              aurizon                              aurizon
# 56                         beach energy                         beach energy
# 57                           federation                           federation
# 58                  hillgrove resources                  hillgrove resources
# 59                     inova  resources                      inova resources
# 60                          asaleo care                          asaleo care
# 61                      ausnet services                      ausnet services
# 62                        crown resorts                        crown resorts
# 63                      aeris resources                      aeris resources
# 64                        broadspectrum                        broadspectrum
# 65                                cimic                                cimic
# 66           cleanaway waste management           cleanaway waste management
# 67  event hospitality and entertainment  event hospitality and entertainment
# 68                     alkane resources                     alkane resources
# 69                               capral                               capral
# 70                    central petroleum                    central petroleum
# 71                            lendlease                            lendlease
# 72                   a.c.n. 004 410 833                    a.c.n 004 410 833
# 73                               cudeco                               cudeco
# 74                             jb hi-fi                             jb hi-fi
# 75              australian pacific coal              australian pacific coal
# 76                        bounty mining                        bounty mining
# 77           alliance aviation services           alliance aviation services
# 78                       aurelia metals                       aurelia metals
# 79                                  bhp                                  bhp
# 80                     bingo industries                     bingo industries
# 81                                coles                                coles
# 82                          dacian gold                          dacian gold
# 83                   gascoyne resources                   gascoyne resources
# 84                              inghams                              inghams
# 85                                adbri                                adbri
# 86                                ampol                                ampol
# 87                                  igo                                  igo
# 88                   image resources nl                   image resources nl
# 89                    eagers automotive                    eagers automotive
# 90                             29metals                             29metals
#
#    ticker  matched  match_score
# 0    ABB1        1          100
# 1    ABY1        1          100
# 2     AGL        1          100
# 3     AMP        1          100
# 4     AOE        1          100
# 5     AIO        1          100
# 6     BBI        1          100
# 7     BSL        1          100
# 8     BLD        1          100
# 9     BKN        1          100
# 10    BKW        1          100
# 11    CEY        1          100
# 12    CEP        1          100
# 13    CCL        1          100
# 14    CBA        1          100
# 15    CSR        1          100
# 16    DXS        1          100
# 17    DOW        1          100
# 18   ENE1        1          100
# 19   ENV1        1          100
# 20   FLX1        1          100
# 21    FMG        1          100
# 22   FGL1        1          100
# 23    GFF        1          100
# 24    GNC        1          100
# 25    GRR        1          100
# 26    HVN        1          100
# 27    HRL        1          100
# 28    ILU        1          100
# 29    IPL        1          100
# 30    BGA        1          100
# 31    CRG        1          100
# 32    DJS        1          100
# 33    FXJ        1          100
# 34    HSO        1          100
# 35    KZL        1          100
# 36    ALG        1          100
# 37    AHG        1          100
# 38   CBH1        1          100
# 39    CHC        1          100
# 40    CSL        1          100
# 41    ESG        1          100
# 42    ELD        1          100
# 43    EPW        1          100
# 44    GCL        1          100
# 45    GNS        1          100
# 46   IPG2        1          100
# 47    LAU        1          100
# 48    AEJ        1          100
# 49   CNG1        1          100
# 50    CER        1          100
# 51    EVN        1          100
# 52    FML        1          100
# 53    IGR        1          100
# 54    AGO        1          100
# 55    AZJ        1          100
# 56    BPT        1          100
# 57   FDR1        1          100
# 58    HGO        1          100
# 59    IVA        1           97
# 60    AHY        1          100
# 61    AST        1          100
# 62    CWN        1          100
# 63    AIS        1          100
# 64    BRS        1          100
# 65    CIM        1          100
# 66    CWY        1          100
# 67    EVT        1          100
# 68    ALK        1          100
# 69    CAA        1          100
# 70    CTP        1          100
# 71    LLC        1          100
# 72    ARI        1           97
# 73    CDU        1          100
# 74    JBH        1          100
# 75    AQC        1          100
# 76    B2Y        1          100
# 77    AQZ        1          100
# 78    AMI        1          100
# 79    BHP        1          100
# 80    BIN        1          100
# 81    CGJ        1          100
# 82    DCN        1          100
# 83    GCY        1          100
# 84    ING        1          100
# 85    ABC        1          100
# 86    ALD        1          100
# 87    IGO        1          100
# 88    IMA        1          100
# 89    APE        1          100
# 90    29M        1          100
